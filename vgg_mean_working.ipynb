# %%
import cv2
import numpy as np

# %%
img = cv2.imread('data/train/cat.0.jpg')

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
img.shape
# Out:
# (374, 500, 3)

# %%
img = cv2.resize(img, (50, 50))

# %%
img.shape
# Out:
# (50, 50, 3)

# %%
img
# Out:
# array([[[ 91, 168, 207],
#         [ 98, 176, 217],
#         [105, 183, 226],
#         ...,
#         [145, 219, 249],
#         [133, 212, 248],
#         [124, 204, 244]],
#
#        [[ 91, 168, 207],
#         [ 98, 176, 217],
#         [105, 183, 226],
#         ...,
#         [147, 221, 251],
#         [141, 216, 247],
#         [129, 208, 246]],
#
#        [[ 93, 166, 210],
#         [100, 174, 218],
#         [103, 178, 222],
#         ...,
#         [145, 219, 249],
#         [135, 218, 246],
#         [136, 214, 247]],
#
#        ...,
#
#        [[ 61, 132, 166],
#         [ 63, 134, 170],
#         [ 66, 137, 174],
#         ...,
#         [  1,   6,   5],
#         [  1,   6,   5],
#         [  1,   4,   4]],
#
#        [[ 56, 127, 161],
#         [ 60, 131, 167],
#         [ 63, 134, 171],
#         ...,
#         [  0,   4,   3],
#         [  0,   4,   3],
#         [  0,   3,   3]],
#
#        [[ 56, 124, 155],
#         [ 59, 129, 161],
#         [ 61, 133, 167],
#         ...,
#         [  1,   3,   3],
#         [  1,   3,   3],
#         [  1,   3,   3]]], dtype=uint8)

# %%
vgg_mean = np.array([123.68, 116.779, 103.939], dtype=np.float32)

# %%
img = img - vgg_mean

# %%
img
# Out:
# array([[[ -32.68     ,   51.221    ,  103.061    ],
#         [ -25.68     ,   59.221    ,  113.061    ],
#         [ -18.68     ,   66.221    ,  122.061    ],
#         ...,
#         [  21.32     ,  102.221    ,  145.061    ],
#         [   9.32     ,   95.221    ,  144.061    ],
#         [   0.3199997,   87.221    ,  140.061    ]],
#
#        [[ -32.68     ,   51.221    ,  103.061    ],
#         [ -25.68     ,   59.221    ,  113.061    ],
#         [ -18.68     ,   66.221    ,  122.061    ],
#         ...,
#         [  23.32     ,  104.221    ,  147.061    ],
#         [  17.32     ,   99.221    ,  143.061    ],
#         [   5.3199997,   91.221    ,  142.061    ]],
#
#        [[ -30.68     ,   49.221    ,  106.061    ],
#         [ -23.68     ,   57.221    ,  114.061    ],
#         [ -20.68     ,   61.221    ,  118.061    ],
#         ...,
#         [  21.32     ,  102.221    ,  145.061    ],
#         [  11.32     ,  101.221    ,  142.061    ],
#         [  12.32     ,   97.221    ,  143.061    ]],
#
#        ...,
#
#        [[ -62.68     ,   15.221001 ,   62.060997 ],
#         [ -60.68     ,   17.221    ,   66.061    ],
#         [ -57.68     ,   20.221    ,   70.061    ],
#         ...,
#         [-122.68     , -110.779    ,  -98.939    ],
#         [-122.68     , -110.779    ,  -98.939    ],
#         [-122.68     , -112.779    ,  -99.939    ]],
#
#        [[ -67.68     ,   10.221001 ,   57.060997 ],
#         [ -63.68     ,   14.221001 ,   63.060997 ],
#         [ -60.68     ,   17.221    ,   67.061    ],
#         ...,
#         [-123.68     , -112.779    , -100.939    ],
#         [-123.68     , -112.779    , -100.939    ],
#         [-123.68     , -113.779    , -100.939    ]],
#
#        [[ -67.68     ,    7.2210007,   51.060997 ],
#         [ -64.68     ,   12.221001 ,   57.060997 ],
#         [ -62.68     ,   16.221    ,   63.060997 ],
#         ...,
#         [-122.68     , -113.779    , -100.939    ],
#         [-122.68     , -113.779    , -100.939    ],
#         [-122.68     , -113.779    , -100.939    ]]], dtype=float32)

# %% [raw]
# [ 91, 168, 207],
# [ 98, 176, 217],
# [105, 183, 226]

# %% [raw]
# [ -32.68     ,   51.221    ,  103.061    ],
# [ -25.68     ,   59.221    ,  113.061    ],
# [ -18.68     ,   66.221    ,  122.061    ]

# %% [raw]
# [123.68, 116.779, 103.939]

# %%
img[:, ::-1]
# Out:
# array([[[   0.3199997,   87.221    ,  140.061    ],
#         [   9.32     ,   95.221    ,  144.061    ],
#         [  21.32     ,  102.221    ,  145.061    ],
#         ...,
#         [ -18.68     ,   66.221    ,  122.061    ],
#         [ -25.68     ,   59.221    ,  113.061    ],
#         [ -32.68     ,   51.221    ,  103.061    ]],
#
#        [[   5.3199997,   91.221    ,  142.061    ],
#         [  17.32     ,   99.221    ,  143.061    ],
#         [  23.32     ,  104.221    ,  147.061    ],
#         ...,
#         [ -18.68     ,   66.221    ,  122.061    ],
#         [ -25.68     ,   59.221    ,  113.061    ],
#         [ -32.68     ,   51.221    ,  103.061    ]],
#
#        [[  12.32     ,   97.221    ,  143.061    ],
#         [  11.32     ,  101.221    ,  142.061    ],
#         [  21.32     ,  102.221    ,  145.061    ],
#         ...,
#         [ -20.68     ,   61.221    ,  118.061    ],
#         [ -23.68     ,   57.221    ,  114.061    ],
#         [ -30.68     ,   49.221    ,  106.061    ]],
#
#        ...,
#
#        [[-122.68     , -112.779    ,  -99.939    ],
#         [-122.68     , -110.779    ,  -98.939    ],
#         [-122.68     , -110.779    ,  -98.939    ],
#         ...,
#         [ -57.68     ,   20.221    ,   70.061    ],
#         [ -60.68     ,   17.221    ,   66.061    ],
#         [ -62.68     ,   15.221001 ,   62.060997 ]],
#
#        [[-123.68     , -113.779    , -100.939    ],
#         [-123.68     , -112.779    , -100.939    ],
#         [-123.68     , -112.779    , -100.939    ],
#         ...,
#         [ -60.68     ,   17.221    ,   67.061    ],
#         [ -63.68     ,   14.221001 ,   63.060997 ],
#         [ -67.68     ,   10.221001 ,   57.060997 ]],
#
#        [[-122.68     , -113.779    , -100.939    ],
#         [-122.68     , -113.779    , -100.939    ],
#         [-122.68     , -113.779    , -100.939    ],
#         ...,
#         [ -62.68     ,   16.221    ,   63.060997 ],
#         [ -64.68     ,   12.221001 ,   57.060997 ],
#         [ -67.68     ,    7.2210007,   51.060997 ]]], dtype=float32)

# %%
x = np.array([-32.68, 51.221, 103.061], dtype=np.float32)
